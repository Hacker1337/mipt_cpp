# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    'figure.figsize':(10, 10)
})

# %%
a = np.loadtxt("answer.txt")
a[:, 0]
a[:, 1]
# Out:
# array([10., 10.,  5.,  5., 10., 10., 13., 13., 14., 14., 13., 13., 14.,
#        14., 18., 18., 14., 14.,  7.,  7.,  2.,  2.,  7.,  7.,  5.,  5.,
#         1.,  1.,  5.,  5., 15., 15., 20., 20., 15., 15., 12., 12., 11.,
#        11., 12., 12., 11., 11.,  7.,  7., 11., 11., 18., 18., 23., 23.,
#        18., 18., 20., 20., 24., 24., 20., 20.])

# %%
n = 110
plt.plot(a[:, 0], a[:, 1], 'o')

plt.plot(a[:n, 0], a[:n, 1], '-')

# %%
plt.plot(a[:, 0], a[:, 1], 'o')
